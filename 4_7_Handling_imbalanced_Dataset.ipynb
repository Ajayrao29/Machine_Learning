# %% [markdown]
# <a href="https://colab.research.google.com/github/Ajayrao29/Machine_Learning/blob/main/4_7_Handling_imbalanced_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Imbalanced Dataset:**
#
# A dataset with an unequal class distribution

# %%
# importing the dependencies
import numpy as np
import pandas as pd

# %%
# loading the dataset to pandas DataFrame
credit_card_data = pd.read_csv('/content/credit_data.csv')

# %%
# first 5 rows of the dataframe
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_data.tail()
# Out:
#          Time        V1        V2        V3        V4        V5        V6  \
# 140698  83876  1.297031  0.260234 -0.165836  0.304460  0.238056 -0.084983
# 140699  83876  1.200272  0.259410  0.397862  0.631576 -0.476806 -0.882324
# 140700  83877 -0.939078  1.234767  1.433774 -0.097576 -0.255769 -0.689204
# 140701  83879  1.170286  0.563313 -0.271928  1.394477 -0.038260 -1.000654
# 140702  83879 -1.376888  0.304186  2.232899 -0.740000       NaN       NaN
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 140698 -0.056115  0.029952 -0.115999  ... -0.315545 -0.948937 -0.024322
# 140699 -0.062362 -0.028223 -0.130967  ... -0.231443 -0.739076  0.151545
# 140700  0.509961  0.153369  0.179511  ... -0.257956 -0.582912  0.080816
# 140701  0.126524 -0.031662  0.139095  ... -0.038141 -0.086158 -0.033513
# 140702       NaN       NaN       NaN  ...       NaN       NaN       NaN
#
#              V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
# distribution of the two classes
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0.0    140438
# 1.0       264
# Name: count, dtype: int64

# %% [markdown]
# This is Highly Imbalanced Dataset as there are more no.of data points for one class (almost 99%).

# %% [markdown]
# 0 --> Legit Transactions
#
# 1 --> Fraudulent Transactions

# %%
# separating the legit and fraudulent transactions
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (140438, 31)
# (264, 31)

# %% [markdown]
# Under-sampling

# %% [markdown]
# Build a sample dataset containing similar distribution of Legit & Fraudulent Transactions

# %% [markdown]
# Number of Fraudulent Transactions --> 492

# %%
legit_sample = legit.sample(n=492)

# %%
print(legit_sample.shape)
# Out:
# (492, 31)

# %% [markdown]
# Concatenate the Two DataFrames

# %%
new_dataset = pd.concat([legit_sample, fraud], axis = 0)

# %%
new_dataset.head()
# Out:
#          Time        V1        V2        V3        V4        V5        V6  \
# 22276   32144 -0.417877  0.889441  0.563499  1.007027 -0.414439 -0.327419
# 32867   36996 -0.644319  1.352500  1.038778  0.942509 -0.083877  0.002730
# 137205  82065 -0.352842 -0.402167  1.018107 -2.707479 -0.674238 -0.150321
# 30506   35959 -1.206680  0.513373  3.419110  1.359352 -0.037222  1.362147
# 136482  81728  1.125586 -0.107005  0.637321  0.727948 -0.408612  0.222830
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 22276   0.366266  0.481008 -0.454656  ...  0.216140  0.384759  0.136104
# 32867   0.048386  0.535724 -0.482521  ... -0.047736 -0.137446 -0.153783
# 137205 -0.391126  0.101120 -2.143315  ...  0.005224  0.219273  0.036835
# 30506   0.391218 -0.832914  2.300603  ... -0.196692  0.922817 -0.569787
# 136482 -0.321048  0.184910  0.349580  ... -0.024529  0.166931 -0.058821
#
#              V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset.tail()
# Out:
#          Time        V1        V2        V3        V4        V5        V6  \
# 125342  77627 -7.139060  2.773082 -6.757845  4.446456 -5.464428 -1.713401
# 128479  78725 -4.312479  1.886476 -2.338634 -0.475243 -1.185444 -2.112079
# 131272  79540 -0.114361  1.036129  1.984405  3.128243 -0.740344  1.548619
# 135718  81372 -0.885254  1.790649 -0.945149  3.853433 -1.543510  0.188582
# 137705  82289 -1.464897  1.975528 -1.077145  2.819191  0.069850 -0.789044
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 125342 -6.485365  3.409395 -3.053493  ...  1.303250 -0.016118 -0.876670
# 128479 -2.122793  0.272565  0.290273  ...  0.550541 -0.067870 -1.114692
# 131272 -1.701284 -2.203842 -1.242265  ... -1.032935  1.196428 -0.112857
# 135718 -2.988383  1.344059 -2.294535  ...  0.746160  0.550802 -0.034882
# 137705 -1.196101  0.673654 -1.363724  ...  0.174099 -0.272505 -0.031549
#
#              V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0.0    492
# 1.0    264
# Name: count, dtype: int64
